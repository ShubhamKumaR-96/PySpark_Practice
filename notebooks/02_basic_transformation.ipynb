# %%
# Spark Session

from pyspark.sql import SparkSession

spark = SparkSession.builder\
        .appName("Spark_Intro")\
        .master("local[*]")\
        .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://aa86f408f643:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark_Intro</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
emp_data = [
    (1, 101, "Shubh", 25, "Male", 50000.0, "2022-05-10"),
    (2, 102, "Anita", 30, "Female", 60000.0, "2021-03-15"),
    (3, 101, "Ravi", 28, "Male", 55000.0, "2020-07-20"),
    (4, 103, "Priya", 35, "Female", 75000.0, "2019-11-01"),
    (5, 104, "Amit", 40, "Male", 80000.0, "2018-01-12"),
    (6, 102, "Neha", 27, "Female", 52000.0, "2023-02-18"),
    (7, 105, "Karan", 32, "Male", 65000.0, "2020-09-25"),
    (8, 101, "Meena", 29, "Female", 58000.0, "2021-06-30"),
    (9, 106, "Vikas", 33, "Male", 70000.0, "2017-04-14"),
    (10, 104, "Sonia", 31, "Female", 62000.0, "2022-08-05"),
    (11, 103, "Arjun", 26, "Male", 48000.0, "2023-01-10"),
    (12, 105, "Pooja", 34, "Female", 77000.0, "2019-12-22"),
    (13, 106, "Rahul", 29, "Male", 56000.0, "2020-03-19"),
    (14, 102, "Sneha", 28, "Female", 54000.0, "2021-09-11"),
    (15, 101, "Deepak", 36, "Male", 82000.0, "2018-05-07"),
    (16, 104, "Kavita", 30, "Female", 61000.0, "2022-10-01"),
    (17, 103, "Manish", 27, "Male", 50000.0, "2023-04-15"),
    (18, 105, "Ritu", 33, "Female", 69000.0, "2019-07-09"),
    (19, 106, "Suresh", 38, "Male", 90000.0, "2017-02-28"),
    (20, 102, "Alok", 24, "Male", 47000.0, "2023-05-20")
]

emp_schema = "employee_id string, department_id string, name string, age string, gender string, salary string, hire_date string"

# %%
# Create emp dataframe

emp_df = spark.createDataFrame(emp_data,emp_schema)

# %%
# Show data (Action)
emp_df.show()
# Out:
# +-----------+-------------+------+---+------+-------+----------+
# |employee_id|department_id|  name|age|gender| salary| hire_date|
# +-----------+-------------+------+---+------+-------+----------+
# |          1|          101| Shubh| 25|  Male|50000.0|2022-05-10|
# |          2|          102| Anita| 30|Female|60000.0|2021-03-15|
# |          3|          101|  Ravi| 28|  Male|55000.0|2020-07-20|
# |          4|          103| Priya| 35|Female|75000.0|2019-11-01|
# |          5|          104|  Amit| 40|  Male|80000.0|2018-01-12|
# |          6|          102|  Neha| 27|Female|52000.0|2023-02-18|
# |          7|          105| Karan| 32|  Male|65000.0|2020-09-25|
# |          8|          101| Meena| 29|Female|58000.0|2021-06-30|
# |          9|          106| Vikas| 33|  Male|70000.0|2017-04-14|
# |         10|          104| Sonia| 31|Female|62000.0|2022-08-05|
# |         11|          103| Arjun| 26|  Male|48000.0|2023-01-10|
# |         12|          105| Pooja| 34|Female|77000.0|2019-12-22|
# |         13|          106| Rahul| 29|  Male|56000.0|2020-03-19|
# |         14|          102| Sneha| 28|Female|54000.0|2021-09-11|
# |         15|          101|Deepak| 36|  Male|82000.0|2018-05-07|
# |         16|          104|Kavita| 30|Female|61000.0|2022-10-01|
# |         17|          103|Manish| 27|  Male|50000.0|2023-04-15|
# |         18|          105|  Ritu| 33|Female|69000.0|2019-07-09|
# |         19|          106|Suresh| 38|  Male|90000.0|2017-02-28|
# |         20|          102|  Alok| 24|  Male|47000.0|2023-05-20|
# +-----------+-------------+------+---+------+-------+----------+

# %%
emp_df.schema
# Out:
# StructType([StructField('employee_id', StringType(), True), StructField('department_id', StringType(), True), StructField('name', StringType(), True), StructField('age', StringType(), True), StructField('gender', StringType(), True), StructField('salary', StringType(), True), StructField('hire_date', StringType(), True)])

# %%
from pyspark.sql.types import StructType,StructField,StringType,IntegerType

emp_schema = StructType([StructField("name",StringType(),True),\
                        StructField("age",IntegerType(),True)])

# %%
# Columns and expression

from pyspark.sql.functions import col, expr

# emp_df["salary"]
emp_df.salary
# Out:
# Column<'salary'>

# %%
# Select Columns
# Select employee_id, name, age, salary from emp

emp_filtered_col = emp_df.select(col("employee_id"),expr("name"),emp_df.age, emp_df.salary)

# %%
# Show dataframe (ACTIONS)
emp_filtered_col.show()
# Out:
# +-----------+------+---+-------+
# |employee_id|  name|age| salary|
# +-----------+------+---+-------+
# |          1| Shubh| 25|50000.0|
# |          2| Anita| 30|60000.0|
# |          3|  Ravi| 28|55000.0|
# |          4| Priya| 35|75000.0|
# |          5|  Amit| 40|80000.0|
# |          6|  Neha| 27|52000.0|
# |          7| Karan| 32|65000.0|
# |          8| Meena| 29|58000.0|
# |          9| Vikas| 33|70000.0|
# |         10| Sonia| 31|62000.0|
# |         11| Arjun| 26|48000.0|
# |         12| Pooja| 34|77000.0|
# |         13| Rahul| 29|56000.0|
# |         14| Sneha| 28|54000.0|
# |         15|Deepak| 36|82000.0|
# |         16|Kavita| 30|61000.0|
# |         17|Manish| 27|50000.0|
# |         18|  Ritu| 33|69000.0|
# |         19|Suresh| 38|90000.0|
# |         20|  Alok| 24|47000.0|
# +-----------+------+---+-------+

# %%
# Using expr for select
# Select emp_id as emp_id,name, cast(age as int) as age, salary from emp_filtered

emp_casted = emp_filtered_col.select(expr("employee_id as emp_id" ),emp_filtered_col.name, expr("cast(age as int) as age"),emp_df.salary)

# %%
# Show dataframe (Action)
emp_casted.show()
# Out:
# +------+------+---+-------+
# |emp_id|  name|age| salary|
# +------+------+---+-------+
# |     1| Shubh| 25|50000.0|
# |     2| Anita| 30|60000.0|
# |     3|  Ravi| 28|55000.0|
# |     4| Priya| 35|75000.0|
# |     5|  Amit| 40|80000.0|
# |     6|  Neha| 27|52000.0|
# |     7| Karan| 32|65000.0|
# |     8| Meena| 29|58000.0|
# |     9| Vikas| 33|70000.0|
# |    10| Sonia| 31|62000.0|
# |    11| Arjun| 26|48000.0|
# |    12| Pooja| 34|77000.0|
# |    13| Rahul| 29|56000.0|
# |    14| Sneha| 28|54000.0|
# |    15|Deepak| 36|82000.0|
# |    16|Kavita| 30|61000.0|
# |    17|Manish| 27|50000.0|
# |    18|  Ritu| 33|69000.0|
# |    19|Suresh| 38|90000.0|
# |    20|  Alok| 24|47000.0|
# +------+------+---+-------+

# %%
emp_casted.printSchema()
# Out:
# root
#  |-- emp_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- salary: string (nullable = true)

# %%
# Using selectExpr

emp_casted_1 = emp_filtered_col.selectExpr("employee_id as emp_id", "name", "cast(age as int) as age", "salary")

# %%
emp_casted_1.show()
# Out:
# +------+------+---+-------+
# |emp_id|  name|age| salary|
# +------+------+---+-------+
# |     1| Shubh| 25|50000.0|
# |     2| Anita| 30|60000.0|
# |     3|  Ravi| 28|55000.0|
# |     4| Priya| 35|75000.0|
# |     5|  Amit| 40|80000.0|
# |     6|  Neha| 27|52000.0|
# |     7| Karan| 32|65000.0|
# |     8| Meena| 29|58000.0|
# |     9| Vikas| 33|70000.0|
# |    10| Sonia| 31|62000.0|
# |    11| Arjun| 26|48000.0|
# |    12| Pooja| 34|77000.0|
# |    13| Rahul| 29|56000.0|
# |    14| Sneha| 28|54000.0|
# |    15|Deepak| 36|82000.0|
# |    16|Kavita| 30|61000.0|
# |    17|Manish| 27|50000.0|
# |    18|  Ritu| 33|69000.0|
# |    19|Suresh| 38|90000.0|
# |    20|  Alok| 24|47000.0|
# +------+------+---+-------+

# %%
# Filter emp based on age > 30
# Select emp_id, name, age, salary from emp_casted where age > 30

emp_final = emp_casted.select("emp_id","name","age","salary").where("age > 30")

# %%
emp_final.show()
# Out:
# +------+------+---+-------+
# |emp_id|  name|age| salary|
# +------+------+---+-------+
# |     4| Priya| 35|75000.0|
# |     5|  Amit| 40|80000.0|
# |     7| Karan| 32|65000.0|
# |     9| Vikas| 33|70000.0|
# |    10| Sonia| 31|62000.0|
# |    12| Pooja| 34|77000.0|
# |    15|Deepak| 36|82000.0|
# |    18|  Ritu| 33|69000.0|
# |    19|Suresh| 38|90000.0|
# +------+------+---+-------+

# %%
# Write the data back to CSV

emp_final.write.format("csv").save("/data/outputs/2/emp.csv")

# %%
# Bonus Tip

schema_str = "name string, age int"

# Ques how spark explicitly convert 

from pyspark.sql.types import _parse_datatype_string

schema_spark = _parse_datatype_string(schema_str)

schema_spark
# Out:
# StructType([StructField('name', StringType(), True), StructField('age', IntegerType(), True)])
